# %% [markdown]
# <a href="https://colab.research.google.com/github/Lele237/Codificando-com-Python-DIO-/blob/main/data_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nova seção

# %%
#Importando Pandas
import pandas as pd

# %%
#Importando o data frame
url = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DDF/part-00000-43e5950c-86d9-417d-acb1-51947800b524.c000.csv'
df = pd.read_csv(url, delimiter=";")

# %%
#Abrindo o data frame
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
#remover duplicatas
df.drop_duplicates(inplace=True)

# %%
# Ver valores ausentes
df.isnull().sum()

#Substituir valores ausentes na coluna `paciente_idade` pela média
df['paciente_idade'].fillna(df['paciente_idade'].mean(), inplace=True)

# %%
#corrigindo dados
df['paciente_dataNascimento'] = pd.to_datetime(df['paciente_dataNascimento'])
df['paciente_idade'] = df['paciente_idade'].astype(int)
df['vacina_dataAplicacao'] = pd.to_datetime(df['vacina_dataAplicacao'])

# %%
#Valores categóricos
df['paciente_enumSexoBiologico'] = df['paciente_enumSexoBiologico'].str.upper()
df['paciente_racaCor_valor'] = df['paciente_racaCor_valor'].str.upper()

# %%
#tratando dados inconsistentes

#Mapear valores de raça/cor
raca_cor_map = {
    1: 'BRANCA',
    2: 'PRETA',
    3: 'PARDA',
    4: 'AMARELA',
    99: 'SEM INFORMACAO'
}
df['paciente_racaCor_valor'] = df['paciente_racaCor_codigo'].map(raca_cor_map)

# %%
#Removendo colunas desnecessárias
colunas_remover = ['paciente_endereco_coPais', 'paciente_endereco_nmMunicipio', 'sistema_origem']
df.drop(columns=colunas_remover, inplace=True)

# %%
#Renomeandocolunas

df.rename(columns={
    'paciente_enumSexoBiologico': 'sexo',
    'paciente_racaCor_valor': 'raca_cor',
    'paciente_racaCor_codigo': 'raca_corCodigo',
    'paciente_dataNascimento' : 'data_Nascimento',
    'paciente_endereco_coIbgeMunicipio' : 'coIbgeMunicipio',
    'paciente_endereco_nmPais' : 'nmPais',
    'paciente_endereco_uf' : 'uf',
    'vacina_dataAplicacao': 'data_aplicacao',
    'vacina_descricao_dose': 'dose',
    'vacina_nome': 'vacina',
    'vacina_codigo' : 'codigo',
    'vacina_fabricante_referencia' : 'fabricante_ref',
    'vacina_fabricante_nome' : 'nome_fabricante',
    'vacina_lote' : 'lote',
    'vacina_categoria_codigo' : 'categoria_codigo',
    'vacina_categoria_nome' : 'categoria_nome'

}, inplace=True)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692961 entries, 0 to 1692960
# Data columns (total 29 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   document_id                               object
#  1   paciente_id                               object
#  2   paciente_idade                            int64
#  3   data_Nascimento                           datetime64[ns]
#  4   sexo                                      object
#  5   raca_corCodigo                            float64
#  6   raca_cor                                  object
#  7   coIbgeMunicipio                           float64
#  8   nmPais                                    object
#  9   uf                                        object
#  10  paciente_endereco_cep                     float64
#  11  paciente_nacionalidade_enumNacionalidade  object
#  12  estabelecimento_valor                     int64
#  13  estabelecimento_razaoSocial               object
#  14  estalecimento_noFantasia                  object
#  15  estabelecimento_municipio_codigo          int64
#  16  estabelecimento_municipio_nome            object
#  17  estabelecimento_uf                        object
#  18  vacina_grupoAtendimento_codigo            int64
#  19  vacina_grupoAtendimento_nome              object
#  20  categoria_codigo                          float64
#  21  categoria_nome                            object
#  22  lote                                      object
#  23  nome_fabricante                           object
#  24  fabricante_ref                            object
#  25  data_aplicacao                            datetime64[ns]
#  26  dose                                      object
#  27  codigo                                    int64
#  28  vacina                                    object
# dtypes: datetime64[ns](2), float64(4), int64(5), object(18)
# memory usage: 374.6+ MB
#                                  document_id  \
# 0  53adf5b8-aaa1-413e-81b0-b311f6d5fe26-i0b0
# 1  810059d6-45a9-4533-9f53-f7f1bb691b9f-i0b0
# 2  53b074e6-29a3-43ca-8ce4-6e921fe8cf2d-i0b0
# 3  810bc1fa-aab2-4e72-b02f-99a2728bc722-i0b0
# 4  53b0ab9a-2b73-4ff1-92ff-ed496ec6cbbe-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  ce8bedc8cd2aee6588531868de7f88211d8a4538ee5570...              24
# 1  1ec0f21f1ede19fe7a5a9d8afc3935ec17d0ddc0e33444...              48
# 2  509b97aff41547dbc9740409ec5e6248c7598125690e0f...              35
# 3  ca2f42c0a669e5f60e4cc73afdf1a82b28b9ab44283730...              49
# 4  5d0ce88994f84d608895eff2e6918b806b868f56d61ba9...              50
#
#   data_Nascimento sexo  raca_corCodigo        raca_cor  coIbgeMunicipio  \
# 0      1997-03-14    F             4.0         AMARELA         530010.0
# 1      1973-07-18    F            99.0  SEM INFORMACAO         530010.0
# 2      1985-11-28    F             3.0           PARDA         230540.0
# 3      1972-05-01    M             4.0         AMARELA         220290.0
# 4      1972-08-09    M            99.0  SEM INFORMACAO         530010.0
#
#    nmPais  uf  ...                       vacina_grupoAtendimento_nome  \
# 0  BRASIL  DF  ...  Acadêmicos/estudantes em estágio em estabeleci...
# 1  BRASIL  DF  ...                              Técnico de Enfermagem
# 2  BRASIL  CE  ...                            Pessoas de 18 a 64 anos
# 3  BRASIL  PI  ...                            Pessoas de 18 a 64 anos
# 4  BRASIL  DF  ...                                       Caminhoneiro
#
#   categoria_codigo               categoria_nome        lote  \
# 0              9.0       Trabalhadores de Saúde  216VCD189Z
# 1              9.0       Trabalhadores de Saúde      FP7082
# 2              2.0                 Faixa Etária      FH4750
# 3              2.0                 Faixa Etária      FA9095
# 4             10.0  Trabalhadores de Transporte     PCA0081
#
#        nome_fabricante               fabricante_ref data_aplicacao  \
# 0  ASTRAZENECA/FIOCRUZ  Organization/33781055000135     2021-07-26
# 1               PFIZER                        28290     2022-06-15
# 2               PFIZER  Organization/00394544000851     2021-10-27
# 3               PFIZER  Organization/00394544000851     2021-07-08
# 4               PFIZER                        28290     2022-11-04
#
#          dose  codigo                                     vacina
# 0     2ª Dose      85  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD
# 1  2º Reforço      87                COVID-19 PFIZER - COMIRNATY
# 2     2ª Dose      87                COVID-19 PFIZER - COMIRNATY
# 3     1ª Dose      87                COVID-19 PFIZER - COMIRNATY
# 4  2º Reforço      87                COVID-19 PFIZER - COMIRNATY
#
# [5 rows x 29 columns]
